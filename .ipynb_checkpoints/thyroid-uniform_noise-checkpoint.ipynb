# %%
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import datasets, mixture
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice
import h5py 


from evaluation import *
np.random.seed(5)

# %%
from sklearn.mixture import GaussianMixture

# %%
import scipy.io
mat = scipy.io.loadmat('/Users/OlgaKo/Desktop/one_plus_e/datasets/thyroid.mat')

X_data = mat["X"]
X_data = StandardScaler().fit_transform(X_data)

labels = mat["y"]

# %%
from sklearn.model_selection import train_test_split
indx_train, indx_test = train_test_split(np.arange(len(labels), dtype='int32'), stratify=labels, test_size=0.5, random_state = 5)

# %%
y_train = labels[indx_train]
y_test = labels[indx_test]

X_train = X_data[indx_train]
X_test = X_data[indx_test]

# %%
X_good = X_train[np.where(y_train==0)[0]]

# %%
X_good.shape, X_train.shape, X_data.shape
# Out:
# ((1840, 6), (1886, 6), (3772, 6))

# %%
gm = GaussianMixture(n_components=7, n_init=6, verbose=2)

# %%
gm.fit(X_good)
# Out:
# Initialization 0
#   Iteration 0	 time lapse 0.03549s	 ll change inf
#   Iteration 10	 time lapse 0.05646s	 ll change 0.02768
#   Iteration 20	 time lapse 0.04630s	 ll change 0.00724
#   Iteration 30	 time lapse 0.04633s	 ll change 0.00547
#   Iteration 40	 time lapse 0.05851s	 ll change 0.00105
# Initialization converged: True	 time lapse 0.24954s	 ll -1.68648
# Initialization 1
#   Iteration 0	 time lapse 0.02747s	 ll change inf
#   Iteration 10	 time lapse 0.05873s	 ll change 0.00985
#   Iteration 20	 time lapse 0.04759s	 ll change 0.00867
# Initialization converged: True	 time lapse 0.16511s	 ll -1.86556
# Initialization 2
#   Iteration 0	 time lapse 0.02948s	 ll change inf
#   Iteration 10	 time lapse 0.05375s	 ll change 0.02410
#   Iteration 20	 time lapse 0.06027s	 ll change 0.00447
#   Iteration 30	 time lapse 0.04681s	 ll change 0.00357
#   Iteration 40	 time lapse 0.04887s	 ll change 0.00352
#   Iteration 50	 time lapse 0.04859s	 ll change 0.00199
# Initialization converged: True	 time lapse 0.29365s	 ll -1.49060
# Initialization 3
#   Iteration 0	 time lapse 0.03019s	 ll change inf
#   Iteration 10	 time lapse 0.04525s	 ll change 0.02577
#   Iteration 20	 time lapse 0.04593s	 ll change 0.00354
#   Iteration 30	 time lapse 0.04650s	 ll change 0.00324
#   Iteration 40	 time lapse 0.04423s	 ll change 0.00309
#   Iteration 50	 time lapse 0.05001s	 ll change 0.06019
# Initialization converged: True	 time lapse 0.27933s	 ll -1.48965
# Initialization 4
#   Iteration 0	 time lapse 0.02180s	 ll change inf
#   Iteration 10	 time lapse 0.04269s	 ll change 0.01545
#   Iteration 20	 time lapse 0.04338s	 ll change 0.00174
# Initialization converged: True	 time lapse 0.11637s	 ll -1.86531
# Initialization 5
#   Iteration 0	 time lapse 0.03750s	 ll change inf
#   Iteration 10	 time lapse 0.04864s	 ll change 0.02481
#   Iteration 20	 time lapse 0.04430s	 ll change 0.00539
#   Iteration 30	 time lapse 0.04517s	 ll change 0.00361
#   Iteration 40	 time lapse 0.04450s	 ll change 0.00785
# Initialization converged: True	 time lapse 0.25965s	 ll -1.49136
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#         means_init=None, n_components=7, n_init=6, precisions_init=None,
#         random_state=None, reg_covar=1e-06, tol=0.001, verbose=2,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
from scipy.stats import multivariate_normal

# %%
n_samples = X_good.shape[0]

# %%
gen = np.array(multivariate_normal.rvs(mean=gm.means_[0], cov=gm.covariances_[0], size=int(gm.weights_[0]*n_samples)))
for d in range(1,gm.n_components):
    gen=np.vstack((gen,multivariate_normal.rvs(mean=gm.means_[d], cov=gm.covariances_[d], size=int(gm.weights_[d]*n_samples))))
np.random.shuffle(gen)
gen = np.array(gen)

# %%
probabilities = np.empty((gm.n_components, gen.shape[0]))

# %%
for d in range(gm.n_components):
    probabilities[d] = multivariate_normal.pdf(gen, mean=gm.means_[d], 
                                                    cov=gm.covariances_[d], allow_singular=True)

# %%
gen.shape
# Out:
# (1836, 6)

# %%
maxprob = np.max(probabilities, axis = 0)
gen_w = 1./(maxprob+1e-2)

# %%
#indices = gen_w.argsort()[-50:][::-1] #_toobig
#indices_toosmall = gen_w.argsort()[:200][::-1]

#indices = np.concatenate((indices_toosmall,indices_toobig))

# %%
#gen_w = np.delete(gen_w, indices)
#gen = np.delete(gen, indices, axis = 0)

# %%
plt.scatter(np.arange(len(gen_w)), gen_w)
plt.show()

# %%
weights = np.ones((n_samples,1)) #X_train.shape[0]

# %%
gen_w_normed = gen_w/np.sum(gen_w)*np.sum(weights)

# %%
gen_w_normed.sum(), np.sum(weights)
# Out:
# (1840.0, 1840.0)

# %%
y1 = np.zeros((n_samples,1))
y2 = np.ones((gen.shape[0],1))

# %%
X_mix = np.vstack((X_good, gen)) #X_good

y_mix = np.vstack((y1, y2)) #y_train

weights_mix = np.vstack((weights.reshape(-1,1), gen_w_normed.reshape(-1,1))).reshape(-1)

# %%
weights_mix.shape
# Out:
# (3676,)

# %%
import tensorflow as tf

s = tf.InteractiveSession()

import keras
from keras.models import Sequential
from keras import layers as L
# Out:
# Using TensorFlow backend.

# %%
net = Sequential()
net.add(L.Dense(64, input_shape=(6,), activation = 'relu'))
#net.add(L.BatchNormalization())
#net.add(L.Dense(32, activation='relu'))
net.add(L.BatchNormalization())
net.add(L.Dropout(0.2))
net.add(L.Dense(1, activation='sigmoid'))

adam = keras.optimizers.Adam(lr=0.001)
net.compile(optimizer=adam, loss='binary_crossentropy')

# %%
history = net.fit(X_mix, y_mix, batch_size=256, epochs=120, validation_split = 0.1, verbose=2, shuffle=True, sample_weight=weights_mix)
# Out:
# Train on 3308 samples, validate on 368 samples
# Epoch 1/120
# 0s - loss: 1.2881 - val_loss: 0.9981
# Epoch 2/120
# 0s - loss: 1.0406 - val_loss: 0.9099
# Epoch 3/120
# 0s - loss: 0.8971 - val_loss: 0.8515
# Epoch 4/120
# 0s - loss: 0.7757 - val_loss: 0.8533
# Epoch 5/120
# 0s - loss: 0.6904 - val_loss: 0.8621
# Epoch 6/120
# 0s - loss: 0.6410 - val_loss: 0.8779
# Epoch 7/120
# 0s - loss: 0.6199 - val_loss: 0.9146
# Epoch 8/120
# 0s - loss: 0.6049 - val_loss: 0.9461
# Epoch 9/120
# 0s - loss: 0.5583 - val_loss: 0.9653
# Epoch 10/120
# 0s - loss: 0.5699 - val_loss: 0.9771
# Epoch 11/120
# 0s - loss: 0.5327 - val_loss: 0.9926
# Epoch 12/120
# 0s - loss: 0.5528 - val_loss: 1.0018
# Epoch 13/120
# 0s - loss: 0.5299 - val_loss: 1.0056
# Epoch 14/120
# 0s - loss: 0.5367 - val_loss: 0.9984
# Epoch 15/120
# 0s - loss: 0.5515 - val_loss: 0.9780
# Epoch 16/120
# 0s - loss: 0.5258 - val_loss: 0.9621
# Epoch 17/120
# 0s - loss: 0.5174 - val_loss: 0.9538
# Epoch 18/120
# 0s - loss: 0.5285 - val_loss: 0.9463
# Epoch 19/120
# 0s - loss: 0.5088 - val_loss: 0.9169
# Epoch 20/120
# 0s - loss: 0.5239 - val_loss: 0.8826
# Epoch 21/120
# 0s - loss: 0.5023 - val_loss: 0.8688
# Epoch 22/120
# 0s - loss: 0.5277 - val_loss: 0.8414
# Epoch 23/120
# 0s - loss: 0.5111 - val_loss: 0.8185
# Epoch 24/120
# 0s - loss: 0.5138 - val_loss: 0.7933
# Epoch 25/120
# 0s - loss: 0.5051 - val_loss: 0.7770
# Epoch 26/120
# 0s - loss: 0.4930 - val_loss: 0.7840
# Epoch 27/120
# 0s - loss: 0.4809 - val_loss: 0.7791
# Epoch 28/120
# 0s - loss: 0.5106 - val_loss: 0.7461
# Epoch 29/120
# 0s - loss: 0.4894 - val_loss: 0.7133
# Epoch 30/120
# 0s - loss: 0.4923 - val_loss: 0.6991
# Epoch 31/120
# 0s - loss: 0.4824 - val_loss: 0.6965
# Epoch 32/120
# 0s - loss: 0.5083 - val_loss: 0.6893
# Epoch 33/120
# 0s - loss: 0.4826 - val_loss: 0.6791
# Epoch 34/120
# 0s - loss: 0.4933 - val_loss: 0.6666
# Epoch 35/120
# 0s - loss: 0.4886 - val_loss: 0.6594
# Epoch 36/120
# 0s - loss: 0.4777 - val_loss: 0.6435
# Epoch 37/120
# 0s - loss: 0.4885 - val_loss: 0.6455
# Epoch 38/120
# 0s - loss: 0.4808 - val_loss: 0.6399
# Epoch 39/120
# 0s - loss: 0.4716 - val_loss: 0.6369
# Epoch 40/120
# 0s - loss: 0.4704 - val_loss: 0.6306
# Epoch 41/120
# 0s - loss: 0.4761 - val_loss: 0.6147
# Epoch 42/120
# 0s - loss: 0.4748 - val_loss: 0.6077
# Epoch 43/120
# 0s - loss: 0.4882 - val_loss: 0.6009
# Epoch 44/120
# 0s - loss: 0.4866 - val_loss: 0.6019
# Epoch 45/120
# 0s - loss: 0.4548 - val_loss: 0.5970
# Epoch 46/120
# 0s - loss: 0.4814 - val_loss: 0.5940
# Epoch 47/120
# 0s - loss: 0.4712 - val_loss: 0.5864
# Epoch 48/120
# 0s - loss: 0.4665 - val_loss: 0.5802
# Epoch 49/120
# 0s - loss: 0.4629 - val_loss: 0.5864
# Epoch 50/120
# 0s - loss: 0.4749 - val_loss: 0.5860
# Epoch 51/120
# 0s - loss: 0.4618 - val_loss: 0.5911
# Epoch 52/120
# 0s - loss: 0.4730 - val_loss: 0.5807
# Epoch 53/120
# 0s - loss: 0.4775 - val_loss: 0.5709
# Epoch 54/120
# 0s - loss: 0.4765 - val_loss: 0.5627
# Epoch 55/120
# 0s - loss: 0.4653 - val_loss: 0.5667
# Epoch 56/120
# 0s - loss: 0.4534 - val_loss: 0.5785
# Epoch 57/120
# 0s - loss: 0.4506 - val_loss: 0.5759
# Epoch 58/120
# 0s - loss: 0.4635 - val_loss: 0.5790
# Epoch 59/120
# 0s - loss: 0.4765 - val_loss: 0.5822
# Epoch 60/120
# 0s - loss: 0.4400 - val_loss: 0.5765
# Epoch 61/120
# 0s - loss: 0.4589 - val_loss: 0.5699
# Epoch 62/120
# 0s - loss: 0.4516 - val_loss: 0.5630
# Epoch 63/120
# 0s - loss: 0.4520 - val_loss: 0.5708
# Epoch 64/120
# 0s - loss: 0.4581 - val_loss: 0.5774
# Epoch 65/120
# 0s - loss: 0.4454 - val_loss: 0.5731
# Epoch 66/120
# 0s - loss: 0.4510 - val_loss: 0.5677
# Epoch 67/120
# 0s - loss: 0.4493 - val_loss: 0.5635
# Epoch 68/120
# 0s - loss: 0.4546 - val_loss: 0.5637
# Epoch 69/120
# 0s - loss: 0.4654 - val_loss: 0.5464
# Epoch 70/120
# 0s - loss: 0.4634 - val_loss: 0.5523
# Epoch 71/120
# 0s - loss: 0.4505 - val_loss: 0.5654
# Epoch 72/120
# 0s - loss: 0.4624 - val_loss: 0.5612
# Epoch 73/120
# 0s - loss: 0.4518 - val_loss: 0.5531
# Epoch 74/120
# 0s - loss: 0.4453 - val_loss: 0.5544
# Epoch 75/120
# 0s - loss: 0.4551 - val_loss: 0.5684
# Epoch 76/120
# 0s - loss: 0.4393 - val_loss: 0.5647
# Epoch 77/120
# 0s - loss: 0.4542 - val_loss: 0.5686
# Epoch 78/120
# 0s - loss: 0.4523 - val_loss: 0.5714
# Epoch 79/120
# 0s - loss: 0.4416 - val_loss: 0.5682
# Epoch 80/120
# 0s - loss: 0.4376 - val_loss: 0.5714
# Epoch 81/120
# 0s - loss: 0.4391 - val_loss: 0.5692
# Epoch 82/120
# 0s - loss: 0.4323 - val_loss: 0.5766
# Epoch 83/120
# 0s - loss: 0.4365 - val_loss: 0.5693
# Epoch 84/120
# 0s - loss: 0.4262 - val_loss: 0.5641
# Epoch 85/120
# 0s - loss: 0.4516 - val_loss: 0.5685
# Epoch 86/120
# 0s - loss: 0.4244 - val_loss: 0.5795
# Epoch 87/120
# 0s - loss: 0.4330 - val_loss: 0.5643
# Epoch 88/120
# 0s - loss: 0.4459 - val_loss: 0.5630
# Epoch 89/120
# 0s - loss: 0.4428 - val_loss: 0.5674
# Epoch 90/120
# 0s - loss: 0.4330 - val_loss: 0.5693
# Epoch 91/120
# 0s - loss: 0.4455 - val_loss: 0.5714
# Epoch 92/120
# 0s - loss: 0.4397 - val_loss: 0.5670
# Epoch 93/120
# 0s - loss: 0.4346 - val_loss: 0.5729
# Epoch 94/120
# 0s - loss: 0.4301 - val_loss: 0.5735
# Epoch 95/120
# 0s - loss: 0.4332 - val_loss: 0.5781
# Epoch 96/120
# 0s - loss: 0.4363 - val_loss: 0.5762
# Epoch 97/120
# 0s - loss: 0.4194 - val_loss: 0.5765
# Epoch 98/120
# 0s - loss: 0.4315 - val_loss: 0.5777
# Epoch 99/120
# 0s - loss: 0.4266 - val_loss: 0.5756
# Epoch 100/120
# 0s - loss: 0.4176 - val_loss: 0.5768
# Epoch 101/120
# 0s - loss: 0.4407 - val_loss: 0.5774
# Epoch 102/120
# 0s - loss: 0.4257 - val_loss: 0.5660
# Epoch 103/120
# 0s - loss: 0.4414 - val_loss: 0.5632
# Epoch 104/120
# 0s - loss: 0.4253 - val_loss: 0.5715
# Epoch 105/120
# 0s - loss: 0.4361 - val_loss: 0.5723
# Epoch 106/120
# 0s - loss: 0.4361 - val_loss: 0.5701
# Epoch 107/120
# 0s - loss: 0.4346 - val_loss: 0.5663
# Epoch 108/120
# 0s - loss: 0.4338 - val_loss: 0.5553
# Epoch 109/120
# 0s - loss: 0.4381 - val_loss: 0.5506
# Epoch 110/120
# 0s - loss: 0.4330 - val_loss: 0.5488
# Epoch 111/120
# 0s - loss: 0.4433 - val_loss: 0.5524
# Epoch 112/120
# 0s - loss: 0.4345 - val_loss: 0.5488
# Epoch 113/120
# 0s - loss: 0.4389 - val_loss: 0.5492
# Epoch 114/120
# 0s - loss: 0.4323 - val_loss: 0.5566
# Epoch 115/120
# 0s - loss: 0.4331 - val_loss: 0.5626
# Epoch 116/120
# 0s - loss: 0.4301 - val_loss: 0.5541
# Epoch 117/120
# 0s - loss: 0.4362 - val_loss: 0.5589
# Epoch 118/120
# 0s - loss: 0.4345 - val_loss: 0.5575
# Epoch 119/120
# 0s - loss: 0.4186 - val_loss: 0.5604
# Epoch 120/120
# 0s - loss: 0.4360 - val_loss: 0.5553

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower left')
plt.show()

# %%
y_pred = net.predict(X_test, verbose=1)
print ('')
perfomance(y_test, y_pred)
# Out:
# 1024/1886 [===============>..............] - ETA: 0s
# f1_score  0.289230769231
# confusion_matrix
# [[1608  231]
#  [   0   47]]

# %% [markdown]
# ## Classic methods

# %%
y_test_rescale = np.where(y_test == 0, np.ones((y_test.shape)), -np.ones((y_test.shape)))

# %%
from sklearn import svm
from sklearn.ensemble import IsolationForest


classifiers_classic = {
    "One-Class SVM": svm.OneClassSVM(nu=0.03,
                                     kernel="rbf", gamma=1e-5),
    "Isolation Forest": IsolationForest(n_estimators=500,
                                        max_samples=1500,
                                        contamination=0.03,
                                        random_state=10)}


for i, (clf_name, clf) in enumerate(classifiers_classic.items()):
        clf.fit(X_good)
        #scores_pred = clf.decision_function(X_test)
        y_pred = clf.predict(X_test)
        
        print (clf_name)
        print ("recall_score ",recall_score(-y_test_rescale, np.round(-y_pred)))
        print ("precision_score ",precision_score(-y_test_rescale, np.round(-y_pred)))
        print ("f1_score ",f1_score(-y_test_rescale, np.round(-y_pred)))
        print ("confusion_matrix ")
        print (confusion_matrix(-y_test_rescale, np.round(-y_pred)))
        


        Score = clf.decision_function(X_test)
        
        
        precision, recall, _ = precision_recall_curve(-y_test_rescale, -Score)
        pr_auc = auc(recall, precision)

        plt.figure()
        plt.plot(recall, precision, label='PR curve (area = %0.3f)' % pr_auc)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.legend(loc="lower right")
        plt.grid(True)
        plt.show()
        
        fpr, tpr, _ = roc_curve(-y_test_rescale, -Score)
        roc_auc = auc(fpr, tpr)
        
        plt.figure()
        plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc="lower right")
        plt.grid(True)
        plt.show()
# Out:
# One-Class SVM
# recall_score  0.914893617021
# precision_score  0.405660377358
# f1_score  0.562091503268
# confusion_matrix
# [[1776   63]
#  [   4   43]]
# Isolation Forest
# recall_score  0.978723404255
# precision_score  0.438095238095
# f1_score  0.605263157895
# confusion_matrix
# [[1780   59]
#  [   1   46]]
