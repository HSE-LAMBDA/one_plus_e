# %%
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import datasets, mixture
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice
import h5py 

np.random.seed(0)

# %%
from sklearn.mixture import GaussianMixture

# %%
import scipy.io
mat = scipy.io.loadmat('arrhythmia.mat')

X_data = mat["X"]
X_data = StandardScaler().fit_transform(X_data)

labels = mat["y"]

# %%
from sklearn.model_selection import train_test_split
indx_train, indx_test = train_test_split(np.arange(len(labels), dtype='int32'), stratify=labels, test_size=0.5, random_state = 1)

# %%
y_train = labels[indx_train]
y_test = labels[indx_test]

X_train = X_data[indx_train]
X_test = X_data[indx_test]

# %%
X_good = X_train[np.where(y_train==0)[0]]

# %%
X_good.shape, X_train.shape, X_data.shape
# Out:
# ((193, 274), (226, 274), (452, 274))

# %%
gm = GaussianMixture(n_components=170, n_init=3, verbose=2)

# %%
gm.fit(X_good)
# Out:
# Initialization 0
#   Iteration 0	 time lapse 4.13264s	 ll change inf
# Initialization converged: True	 time lapse 6.17221s	 ll 1632.81919
# Initialization 1
#   Iteration 0	 time lapse 4.89431s	 ll change inf
# Initialization converged: True	 time lapse 7.37248s	 ll 1632.81692
# Initialization 2
#   Iteration 0	 time lapse 3.93114s	 ll change inf

# %%
from scipy.stats import multivariate_normal

# %%
n_samples = X_good.shape[0]

# %%
gen = np.array(multivariate_normal.rvs(mean=gm.means_[0], cov=gm.covariances_[0], size=int(gm.weights_[0]*n_samples)))
for d in range(1,gm.n_components):
    gen=np.vstack((gen,multivariate_normal.rvs(mean=gm.means_[d], cov=gm.covariances_[d], size=int(gm.weights_[d]*n_samples))))
np.random.shuffle(gen)
gen = np.array(gen)

# %%
probabilities = np.empty((gm.n_components, gen.shape[0]))

# %%
for d in range(gm.n_components):
    probabilities[d] = multivariate_normal.pdf(gen, mean=gm.means_[d], 
                                                    cov=gm.covariances_[d], allow_singular=True)

# %%
gen.shape

# %%
maxprob = np.max(probabilities, axis = 0)
gen_w = 1./maxprob

# %%
maxprob

# %%
indices = gen_w.argsort()[-50:][::-1] #_toobig
#indices_toosmall = gen_w.argsort()[:200][::-1]

#indices = np.concatenate((indices_toosmall,indices_toobig))

# %%
gen_w = np.delete(gen_w, indices)
gen = np.delete(gen, indices, axis = 0)

# %%
plt.scatter(np.arange(len(gen_w)), gen_w)
plt.show()

# %%
weights = np.ones((n_samples,1)) #X_train.shape[0]

# %%
gen_w_normed = gen_w/np.sum(gen_w)*np.sum(weights)

# %%
gen_w_normed.sum(), np.sum(weights)
# Out:
# (1840.0, 1840.0)

# %%
y1 = np.zeros((n_samples,1))
y2 = np.ones((gen.shape[0],1))

# %%
X_mix = np.vstack((X_good, gen)) #X_good

y_mix = np.vstack((y1, y2)) #y_train

weights_mix = np.vstack((weights.reshape(-1,1), gen_w_normed.reshape(-1,1))).reshape(-1)

# %%
weights_mix.shape
# Out:
# (3678,)

# %%
import tensorflow as tf

s = tf.InteractiveSession()

import keras
from keras.models import Sequential
from keras import layers as L

# %%
net = Sequential()
net.add(L.Dense(50, input_shape=(6,), activation = 'relu'))
#net.add(L.Dense(16, activation='relu'))
net.add(L.Dense(1, activation='sigmoid'))

adam = keras.optimizers.Adam(lr=0.001)
net.compile(optimizer=adam, loss='binary_crossentropy')

# %%
history = net.fit(X_mix, y_mix, batch_size=32, epochs=15, validation_split = 0.1, verbose=1, shuffle=True, sample_weight=weights_mix)
# Out:
# Train on 3310 samples, validate on 368 samples
# Epoch 1/15
# 3310/3310 [==============================] - 1s - loss: 0.7332 - val_loss: 0.9286
# Epoch 2/15
# 3310/3310 [==============================] - 0s - loss: 0.6597 - val_loss: 0.7859
# Epoch 3/15
# 3310/3310 [==============================] - 0s - loss: 0.6235 - val_loss: 0.7606
# Epoch 4/15
# 3310/3310 [==============================] - 0s - loss: 0.6021 - val_loss: 0.6799
# Epoch 5/15
# 3310/3310 [==============================] - 0s - loss: 0.5803 - val_loss: 0.6850
# Epoch 6/15
# 3310/3310 [==============================] - 0s - loss: 0.5659 - val_loss: 0.6327
# Epoch 7/15
# 3310/3310 [==============================] - 0s - loss: 0.5521 - val_loss: 0.6701
# Epoch 8/15
# 3310/3310 [==============================] - 0s - loss: 0.5436 - val_loss: 0.6353
# Epoch 9/15
# 3310/3310 [==============================] - 0s - loss: 0.5347 - val_loss: 0.6331
# Epoch 10/15
# 3310/3310 [==============================] - 0s - loss: 0.5251 - val_loss: 0.6023
# Epoch 11/15
# 3310/3310 [==============================] - 0s - loss: 0.5186 - val_loss: 0.5620
# Epoch 12/15
# 3310/3310 [==============================] - 0s - loss: 0.5121 - val_loss: 0.5905
# Epoch 13/15
# 3310/3310 [==============================] - 0s - loss: 0.5060 - val_loss: 0.5777
# Epoch 14/15
# 3310/3310 [==============================] - 0s - loss: 0.4996 - val_loss: 0.5859
# Epoch 15/15
# 3310/3310 [==============================] - 0s - loss: 0.4933 - val_loss: 0.5472

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = net.predict(X_test, verbose=1)
# Out:
#   32/1886 [..............................] - ETA: 1s

# %%
perfomance(y_test, y_pred)
# Out:
# f1_score  0.327272727273
# confusion_matrix
# [[1656  183]
#  [   2   45]]
