# %%
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import datasets, mixture
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice
import h5py 

import sys
sys.path.append('../../')

from evaluation import *
np.random.seed(10)
# Out:
# /home/aryzhikov/.conda/envs/lasagne2.7/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from sklearn.mixture import GaussianMixture
from ard_em import GaussianMixtureARD

# %%
import scipy.io
mat = scipy.io.loadmat('../../datasets/thyroid.mat')

X_data = mat["X"]
X_data = StandardScaler().fit_transform(X_data)

labels = mat["y"]

# %%
idx = np.random.permutation(len(labels))
X_data, labels = X_data[idx], labels[idx]

# %%
from sklearn.model_selection import train_test_split
indx_train, indx_test = train_test_split(np.arange(len(labels), dtype='int32'), stratify=labels, test_size=0.5, random_state = 5)

# %%
y_train = labels[indx_train]
y_test = labels[indx_test]

X_train = X_data[indx_train]
X_test = X_data[indx_test]

# %%
X_good = X_train[np.where(y_train==0)[0]]
X_bad = X_train[np.where(y_train==1)[0]]

# %%
X_good.shape, X_train.shape, X_data.shape
# Out:
# ((1840, 6), (1886, 6), (3772, 6))

# %%
# lowest_bic = np.infty
# bic = []
# n_components_range = range(5, 50)
# cv_types = ['spherical', 'tied', 'diag', 'full']
# for cv_type in cv_types:
#     for n_components in n_components_range:
#         # Fit a Gaussian mixture with EM
#         gmm = mixture.GaussianMixture(n_components=n_components,
#                                       covariance_type=cv_type)
#         gmm.fit(X_good)
#         bic.append(gmm.bic(X_good))
#         if bic[-1] < lowest_bic:
#             lowest_bic = bic[-1]
#             print (n_components, cv_type, lowest_bic)
#             best_gmm = gmm

# gm = GaussianMixture(n_components=19, n_init=6, covariance_type="full", verbose=0)
gm = GaussianMixtureARD(n_init=6, verbose=0)

# %%
gm.fit(X_good)
# Out:
# GaussianMixtureARD(alpha_bound=1000.0, covariance_type='full',
#           init_components='sqrt', init_params='kmeans', max_iter=100,
#           means_init=None, n_init=6, precisions_init=None,
#           random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#           verbose_interval=10, warm_start=False, weight_bound=0.001,
#           weights_init=None)

# %%
gm.bic(X_good)
# Out:
# 2736.2877283790076

# %%
from scipy.stats import multivariate_normal

# %%
n_samples = X_good.shape[0]

# %%
gen = np.array(multivariate_normal.rvs(mean=gm.means_[0], cov=gm.covariances_[0], size=int(gm.weights_[0]*n_samples)))
for d in range(1,gm.n_components):
    gen=np.vstack((gen,multivariate_normal.rvs(mean=gm.means_[d], cov=gm.covariances_[d], size=int(gm.weights_[d]*n_samples))))
np.random.shuffle(gen)
gen = np.array(gen)

# %%
probabilities = np.empty((gm.n_components, gen.shape[0]))

# %%
for d in range(gm.n_components):
    probabilities[d] = multivariate_normal.pdf(gen, mean=gm.means_[d], 
                                                    cov=gm.covariances_[d], allow_singular=True)

# %%
gen.shape
# Out:
# (1828, 6)

# %%
maxprob = np.max(probabilities, axis = 0)
gen_w = 1./(maxprob+1e-2)

# %%
plt.scatter(np.arange(len(gen_w)), gen_w)
plt.show()

# %%
weights = np.ones((n_samples,1)) #X_train.shape[0]

# %%
gen_w_normed = gen_w/np.sum(gen_w)*np.sum(weights)

# %%
gen_w_normed.sum(), np.sum(weights)
# Out:
# (1840.0, 1840.0)

# %%
y1 = np.zeros((n_samples,1))
y2 = np.ones((gen.shape[0],1))

# %%
X_mix = np.vstack((gen, X_good)) 

y_mix = np.vstack((y2, y1))

weights_mix = np.vstack((gen_w_normed.reshape(-1,1), weights.reshape(-1,1))).reshape(-1)

# %%
weights_mix.shape
# Out:
# (3668,)

# %%
import tensorflow as tf

s = tf.InteractiveSession()

import keras
from keras.models import Sequential
from keras import layers as L
# Out:
# Using TensorFlow backend.

# %%
def build_net():
    net = Sequential()
    net.add(L.Dense(80, input_shape=(6,), activation = 'relu'))
    #net.add(L.BatchNormalization())
    #net.add(L.Dense(32, activation='relu'))
    net.add(L.BatchNormalization())
    net.add(L.Dropout(0.2))
    net.add(L.Dense(1, activation='sigmoid'))

    adam = keras.optimizers.Adam(lr=0.001)
    net.compile(optimizer=adam, loss='binary_crossentropy')
    return net

# %%
# summarize history for loss
def history_plot(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='lower left')
    plt.show()

# %%
ours_roc_aucs = {}
ours_pr_aucs = {}

# %%
plt.plot(weights_mix)
plt.show()

# %%
idx = np.random.permutation(len(y_mix))

net = build_net()
history = net.fit(X_mix[idx], y_mix[idx], 
                  batch_size=256, epochs=130, validation_split = 0.1, verbose=2, shuffle=True, 
                  sample_weight=weights_mix[idx])
history_plot(history)
# Out:
# Train on 3301 samples, validate on 367 samples
# Epoch 1/130
#  - 1s - loss: 1.3818 - val_loss: 1.4338
# Epoch 2/130
#  - 0s - loss: 0.9479 - val_loss: 0.8454
# Epoch 3/130
#  - 0s - loss: 0.7999 - val_loss: 0.6425
# Epoch 4/130
#  - 0s - loss: 0.7253 - val_loss: 0.5684
# Epoch 5/130
#  - 0s - loss: 0.6400 - val_loss: 0.5343
# Epoch 6/130
#  - 0s - loss: 0.6722 - val_loss: 0.5134
# Epoch 7/130
#  - 0s - loss: 0.6086 - val_loss: 0.4957
# Epoch 8/130
#  - 0s - loss: 0.6111 - val_loss: 0.4870
# Epoch 9/130
#  - 0s - loss: 0.5774 - val_loss: 0.4770
# Epoch 10/130
#  - 0s - loss: 0.5855 - val_loss: 0.4677
# Epoch 11/130
#  - 0s - loss: 0.5917 - val_loss: 0.4574
# Epoch 12/130
#  - 0s - loss: 0.5608 - val_loss: 0.4497
# Epoch 13/130
#  - 0s - loss: 0.5492 - val_loss: 0.4464
# Epoch 14/130
#  - 0s - loss: 0.5417 - val_loss: 0.4344
# Epoch 15/130
#  - 0s - loss: 0.5561 - val_loss: 0.4358
# Epoch 16/130
#  - 0s - loss: 0.5487 - val_loss: 0.4341
# Epoch 17/130
#  - 0s - loss: 0.5594 - val_loss: 0.4374
# Epoch 18/130
#  - 0s - loss: 0.5779 - val_loss: 0.4446
# Epoch 19/130
#  - 0s - loss: 0.5409 - val_loss: 0.4340
# Epoch 20/130
#  - 0s - loss: 0.5268 - val_loss: 0.4206
# Epoch 21/130
#  - 0s - loss: 0.5563 - val_loss: 0.4192
# Epoch 22/130
#  - 0s - loss: 0.5359 - val_loss: 0.4191
# Epoch 23/130
#  - 0s - loss: 0.5370 - val_loss: 0.4214
# Epoch 24/130
#  - 0s - loss: 0.5199 - val_loss: 0.4157
# Epoch 25/130
#  - 0s - loss: 0.5165 - val_loss: 0.4149
# Epoch 26/130
#  - 0s - loss: 0.5228 - val_loss: 0.4183
# Epoch 27/130
#  - 0s - loss: 0.5263 - val_loss: 0.4190
# Epoch 28/130
#  - 0s - loss: 0.5326 - val_loss: 0.4182
# Epoch 29/130
#  - 0s - loss: 0.5103 - val_loss: 0.4221
# Epoch 30/130
#  - 0s - loss: 0.4921 - val_loss: 0.4157
# Epoch 31/130
#  - 0s - loss: 0.5028 - val_loss: 0.4118
# Epoch 32/130
#  - 0s - loss: 0.4928 - val_loss: 0.4096
# Epoch 33/130
#  - 0s - loss: 0.5048 - val_loss: 0.4087
# Epoch 34/130
#  - 0s - loss: 0.5231 - val_loss: 0.4063
# Epoch 35/130
#  - 0s - loss: 0.4697 - val_loss: 0.4069
# Epoch 36/130
#  - 0s - loss: 0.5078 - val_loss: 0.4049
# Epoch 37/130
#  - 0s - loss: 0.4955 - val_loss: 0.4061
# Epoch 38/130
#  - 0s - loss: 0.5348 - val_loss: 0.4103
# Epoch 39/130
#  - 0s - loss: 0.5085 - val_loss: 0.4118
# Epoch 40/130
#  - 0s - loss: 0.4968 - val_loss: 0.4119
# Epoch 41/130
#  - 0s - loss: 0.4863 - val_loss: 0.4118
# Epoch 42/130
#  - 0s - loss: 0.4842 - val_loss: 0.4162
# Epoch 43/130
#  - 0s - loss: 0.4820 - val_loss: 0.4130
# Epoch 44/130
#  - 0s - loss: 0.4731 - val_loss: 0.4109
# Epoch 45/130
#  - 0s - loss: 0.4929 - val_loss: 0.4076
# Epoch 46/130
#  - 0s - loss: 0.4908 - val_loss: 0.4048
# Epoch 47/130
#  - 0s - loss: 0.4853 - val_loss: 0.4066
# Epoch 48/130
#  - 0s - loss: 0.4776 - val_loss: 0.4111
# Epoch 49/130
#  - 0s - loss: 0.4969 - val_loss: 0.4077
# Epoch 50/130
#  - 0s - loss: 0.4873 - val_loss: 0.4070
# Epoch 51/130
#  - 0s - loss: 0.4800 - val_loss: 0.4059
# Epoch 52/130
#  - 0s - loss: 0.4649 - val_loss: 0.4098
# Epoch 53/130
#  - 0s - loss: 0.4821 - val_loss: 0.4057
# Epoch 54/130
#  - 0s - loss: 0.4674 - val_loss: 0.4016
# Epoch 55/130
#  - 0s - loss: 0.4518 - val_loss: 0.4024
# Epoch 56/130
#  - 0s - loss: 0.4664 - val_loss: 0.4012
# Epoch 57/130
#  - 0s - loss: 0.4726 - val_loss: 0.4031
# Epoch 58/130
#  - 0s - loss: 0.4630 - val_loss: 0.3984
# Epoch 59/130
#  - 0s - loss: 0.4631 - val_loss: 0.3983
# Epoch 60/130
#  - 0s - loss: 0.4485 - val_loss: 0.3959
# Epoch 61/130
#  - 0s - loss: 0.4664 - val_loss: 0.3972
# Epoch 62/130
#  - 0s - loss: 0.4571 - val_loss: 0.3965
# Epoch 63/130
#  - 0s - loss: 0.4448 - val_loss: 0.3928
# Epoch 64/130
#  - 0s - loss: 0.4555 - val_loss: 0.3905
# Epoch 65/130
#  - 0s - loss: 0.4594 - val_loss: 0.3887
# Epoch 66/130
#  - 0s - loss: 0.4578 - val_loss: 0.3900
# Epoch 67/130
#  - 0s - loss: 0.4430 - val_loss: 0.3856
# Epoch 68/130
#  - 0s - loss: 0.4515 - val_loss: 0.3886
# Epoch 69/130
#  - 0s - loss: 0.4746 - val_loss: 0.3858
# Epoch 70/130
#  - 0s - loss: 0.4459 - val_loss: 0.3839
# Epoch 71/130
#  - 0s - loss: 0.4294 - val_loss: 0.3808
# Epoch 72/130
#  - 0s - loss: 0.4667 - val_loss: 0.3785
# Epoch 73/130
#  - 0s - loss: 0.4361 - val_loss: 0.3849
# Epoch 74/130
#  - 0s - loss: 0.4626 - val_loss: 0.3870
# Epoch 75/130
#  - 0s - loss: 0.4350 - val_loss: 0.3785
# Epoch 76/130
#  - 0s - loss: 0.4422 - val_loss: 0.3810
# Epoch 77/130
#  - 0s - loss: 0.4582 - val_loss: 0.3820
# Epoch 78/130
#  - 0s - loss: 0.4502 - val_loss: 0.3833
# Epoch 79/130
#  - 0s - loss: 0.4373 - val_loss: 0.3760
# Epoch 80/130
#  - 0s - loss: 0.4398 - val_loss: 0.3772
# Epoch 81/130
#  - 0s - loss: 0.4532 - val_loss: 0.3798
# Epoch 82/130
#  - 0s - loss: 0.4373 - val_loss: 0.3785
# Epoch 83/130
#  - 0s - loss: 0.4226 - val_loss: 0.3736
# Epoch 84/130
#  - 0s - loss: 0.4337 - val_loss: 0.3724
# Epoch 85/130
#  - 0s - loss: 0.4597 - val_loss: 0.3771
# Epoch 86/130
#  - 0s - loss: 0.4383 - val_loss: 0.3809
# Epoch 87/130
#  - 0s - loss: 0.4474 - val_loss: 0.3771
# Epoch 88/130
#  - 0s - loss: 0.4551 - val_loss: 0.3761
# Epoch 89/130
#  - 0s - loss: 0.4503 - val_loss: 0.3768
# Epoch 90/130
#  - 0s - loss: 0.4249 - val_loss: 0.3752
# Epoch 91/130
#  - 0s - loss: 0.4484 - val_loss: 0.3773
# Epoch 92/130
#  - 0s - loss: 0.4206 - val_loss: 0.3752
# Epoch 93/130
#  - 0s - loss: 0.4307 - val_loss: 0.3727
# Epoch 94/130
#  - 0s - loss: 0.4497 - val_loss: 0.3835
# Epoch 95/130
#  - 0s - loss: 0.4391 - val_loss: 0.3859
# Epoch 96/130
#  - 0s - loss: 0.4406 - val_loss: 0.3679
# Epoch 97/130
#  - 0s - loss: 0.4407 - val_loss: 0.3733
# Epoch 98/130
#  - 0s - loss: 0.4245 - val_loss: 0.3685
# Epoch 99/130
#  - 0s - loss: 0.4326 - val_loss: 0.3671
# Epoch 100/130
#  - 0s - loss: 0.4279 - val_loss: 0.3745
# Epoch 101/130
#  - 0s - loss: 0.4183 - val_loss: 0.3694
# Epoch 102/130
#  - 0s - loss: 0.4361 - val_loss: 0.3684
# Epoch 103/130
#  - 0s - loss: 0.4236 - val_loss: 0.3698
# Epoch 104/130
#  - 0s - loss: 0.4383 - val_loss: 0.3654
# Epoch 105/130
#  - 0s - loss: 0.4282 - val_loss: 0.3654
# Epoch 106/130
#  - 0s - loss: 0.4186 - val_loss: 0.3682
# Epoch 107/130
#  - 0s - loss: 0.4260 - val_loss: 0.3648
# Epoch 108/130
#  - 0s - loss: 0.4302 - val_loss: 0.3620
# Epoch 109/130
#  - 0s - loss: 0.4219 - val_loss: 0.3643
# Epoch 110/130
#  - 0s - loss: 0.4211 - val_loss: 0.3622
# Epoch 111/130
#  - 0s - loss: 0.4150 - val_loss: 0.3620
# Epoch 112/130
#  - 0s - loss: 0.3996 - val_loss: 0.3594
# Epoch 113/130
#  - 0s - loss: 0.4197 - val_loss: 0.3603
# Epoch 114/130
#  - 0s - loss: 0.4132 - val_loss: 0.3599
# Epoch 115/130
#  - 0s - loss: 0.4049 - val_loss: 0.3565
# Epoch 116/130
#  - 0s - loss: 0.3960 - val_loss: 0.3590
# Epoch 117/130
#  - 0s - loss: 0.4061 - val_loss: 0.3560
# Epoch 118/130
#  - 0s - loss: 0.3984 - val_loss: 0.3535
# Epoch 119/130
#  - 0s - loss: 0.4126 - val_loss: 0.3522
# Epoch 120/130
#  - 0s - loss: 0.4254 - val_loss: 0.3551
# Epoch 121/130
#  - 0s - loss: 0.3987 - val_loss: 0.3554
# Epoch 122/130
#  - 0s - loss: 0.3970 - val_loss: 0.3609
# Epoch 123/130
#  - 0s - loss: 0.3917 - val_loss: 0.3562
# Epoch 124/130
#  - 0s - loss: 0.4178 - val_loss: 0.3498
# Epoch 125/130
#  - 0s - loss: 0.4112 - val_loss: 0.3505
# Epoch 126/130
#  - 0s - loss: 0.4037 - val_loss: 0.3518
# Epoch 127/130
#  - 0s - loss: 0.3895 - val_loss: 0.3525
# Epoch 128/130
#  - 0s - loss: 0.4089 - val_loss: 0.3530
# Epoch 129/130
#  - 0s - loss: 0.3953 - val_loss: 0.3515
# Epoch 130/130
#  - 0s - loss: 0.4059 - val_loss: 0.3491

# %%
y_pred = net.predict(X_test, verbose=1)
ours_pr_aucs['ours with alpha=0.'] = [average_precision_score(y_test, y_pred)]
ours_roc_aucs['ours with alpha=0.'] = [roc_auc_score(y_test, y_pred)]

print ('')
perfomance(y_test, y_pred)
# Out:
# 1886/1886 [==============================] - 0s 81us/step
#
# f1_score  0.308724832215
# confusion_matrix
# [[1634  205]
#  [   1   46]]

# %%
weights_train = np.array(len(y_train)/np.where(y_train == 0.0, len(y_train)-np.sum(y_train), np.sum(y_train)))
plt.scatter(np.arange(len(y_train)),weights_train.ravel())
plt.show()

# %%
import math
n_splits=10
step = math.ceil((X_bad.shape[0]/(n_splits)))

# %%
alpha=1
for i in range(1,n_splits+1):
    if step*i>len(X_bad):
        end_ind=len(X_bad)
    else:   
        end_ind=step*i

    cur_X = np.concatenate((X_good, X_bad[:end_ind]))
    cur_y = np.concatenate((np.zeros((X_good.shape[0],1)), np.ones((end_ind,1)))).ravel()
    cur_w = np.concatenate((np.min(weights_train)*np.ones((X_good.shape[0],1)), np.max(weights_train)*np.ones((end_ind,1)))).ravel()
    
    idx = np.random.permutation(len(cur_y))
    cur_X, cur_y, cur_w = cur_X[idx], cur_y[idx], cur_w[idx]

    net = build_net()
    history = net.fit(cur_X, cur_y, 
                      batch_size=256, epochs=130, validation_split = 0.1, verbose=0, shuffle=True, 
                      sample_weight=cur_w)
    if i==5:
        history_plot(history)

    y_pred=net.predict(X_test)
    if alpha in ours_pr_aucs:
        # append the new number to the existing array at this slot
        ours_pr_aucs[alpha].append(average_precision_score(y_test, y_pred))
        ours_roc_aucs[alpha].append(roc_auc_score(y_test, y_pred))
    else:
        # create a new array in this slot
        ours_pr_aucs[alpha] = [average_precision_score(y_test, y_pred)]
        ours_roc_aucs[alpha] = [roc_auc_score(y_test, y_pred)]

# %%
ours_pr_aucs, ours_roc_aucs
# Out:
# ({1: [0.84583204585042449,
#    0.87589386768602695,
#    0.87389675309950021,
#    0.88215975649688383,
#    0.89186638916879257,
#    0.9152079407232967,
#    0.93122504505830273,
#    0.91812675873387795,
#    0.90502002621854705,
#    0.92872010289320506],
#   'ours with alpha=0.': [0.81085061105545786]},
#  {1: [0.95145372716439325,
#    0.96750083879999538,
#    0.98891627040597929,
#    0.96352087744264348,
#    0.99493249106244142,
#    0.97970682493954864,
#    0.99832240000925565,
#    0.99816042483773559,
#    0.99806208276931263,
#    0.99819513380306135],
#   'ours with alpha=0.': [0.98646350352295997]})

# %%
# net = build_net()
# history = net.fit(X_train, y_train, 
#                   batch_size=256, epochs=120, validation_split = 0.1, verbose=2, shuffle=True, 
#                   sample_weight=np.array(len(y_train)/np.where(y_train == 0.0, len(y_train)-np.sum(y_train), np.sum(y_train))).ravel()
#                   )
# history_plot(history)

# y_pred = net.predict(X_test, verbose=1)
# ours_pr_aucs[1.] = [average_precision_score(y_test, y_pred)]
# ours_roc_aucs[1.] = [roc_auc_score(y_test, y_pred)]

# print ('')
# perfomance(y_test, y_pred)

# %%
alphas = [0.05, 0.1, 0.3, 0.5, 0.9]

# %%
def upd_weights(alpha, y_mix, num_true_bad, w_g = gen_w_normed):
    # sum of weights for good and bad data: beta * bad + (1 - beta) * good
    # proportionf of weights between real and fake data id alpha: alpha * true + (1 - alpha) * fake
    num_good = len(y_mix)-np.sum(y_mix)
    num_fake_bad = np.sum(y_mix)
    sum_w = num_good+num_fake_bad+num_true_bad
    
    beta = 0.5
    w_good = (1-beta)/num_good * np.ones((int(num_good),1))
    
    w_fake_bad = (1-alpha)*beta/num_fake_bad * w_g
    w_fake_bad = w_fake_bad.reshape(-1,1)
    
    if num_true_bad!=0:
        w_true_bad = alpha*beta/num_true_bad *np.ones((int(num_true_bad),1))
    else:
        w_true_bad=np.empty((0,1))
                           
    return sum_w*np.vstack((w_fake_bad, w_good, w_true_bad))

# %%
for alpha in alphas:
    for i in range(0,n_splits+1):
        if step*i>len(X_bad):
            end_ind=len(X_bad)
        else:   
            end_ind=step*i    
            
        cur_X = np.concatenate((X_mix, X_bad[:end_ind]))
        cur_y = np.concatenate((y_mix, np.ones((end_ind,1)))).ravel()
        cur_w = upd_weights(alpha, y_mix, w_g = gen_w_normed, num_true_bad=end_ind).ravel()
        
        idx = np.random.permutation(len(cur_y))    
    
        net = build_net()
        history = net.fit(cur_X[idx], cur_y[idx], 
                          batch_size=256, epochs=130, validation_split = 0.1, verbose=0, shuffle=True, 
                          sample_weight=cur_w[idx])
        if i%3==0:
            print (alpha)
            history_plot(history)
            
            plt.scatter(np.arange(len(cur_w)), cur_w, c = cur_y)#np.concatenate((y_mix, 2*np.ones((end_ind,1)))).ravel())
            plt.show()

        y_pred=net.predict(X_test)
        if alpha in ours_pr_aucs:
            # append the new number to the existing array at this slot
            ours_pr_aucs[alpha].append(average_precision_score(y_test, y_pred))
            ours_roc_aucs[alpha].append(roc_auc_score(y_test, y_pred))
        else:
            # create a new array in this slot
            ours_pr_aucs[alpha] = [average_precision_score(y_test, y_pred)]
            ours_roc_aucs[alpha] = [roc_auc_score(y_test, y_pred)]
# Out:
# 0.05
# 0.05
# 0.05
# 0.05
# 0.1
# 0.1
# 0.1
# 0.1
# 0.3
# 0.3
# 0.3
# 0.3
# 0.5
# 0.5
# 0.5
# 0.5
# 0.9
# 0.9
# 0.9
# 0.9

# %%
ours_pr_aucs
# Out:
# {0.05: [0.75997654184597851,
#   0.77734889649161554,
#   0.80757581457946825,
#   0.82053944561747794,
#   0.85732590424244148,
#   0.76689311308391239,
#   0.80870170651658757,
#   0.80237588402402915,
#   0.82983569228727883,
#   0.81418095767521614,
#   0.77942563545489707],
#  1: [0.84583204585042449,
#   0.87589386768602695,
#   0.87389675309950021,
#   0.88215975649688383,
#   0.89186638916879257,
#   0.9152079407232967,
#   0.93122504505830273,
#   0.91812675873387795,
#   0.90502002621854705,
#   0.92872010289320506],
#  'ours with alpha=0.': [0.81085061105545786],
#  0.5: [0.73354236736929046,
#   0.84932576460772968,
#   0.87550487207546357,
#   0.87790078932382509,
#   0.8626999242277722,
#   0.85076193991048477,
#   0.88614001278886112,
#   0.87167865052443982,
#   0.88438506302803788,
#   0.8669312258423697,
#   0.87507388996079416],
#  0.3: [0.79000231385966313,
#   0.83436188456813198,
#   0.8153769452347408,
#   0.8636627301810994,
#   0.85314787637668321,
#   0.85192420913372224,
#   0.86820861652084191,
#   0.81872609110299155,
#   0.81368407954941657,
#   0.84150034666815454,
#   0.83123282663184483],
#  0.1: [0.80656423999591931,
#   0.81219683417974842,
#   0.85108653389245736,
#   0.86081806339963918,
#   0.81988085892892182,
#   0.84523138182853808,
#   0.84918002516869506,
#   0.84688343493447216,
#   0.81813907089651838,
#   0.75826996089360166,
#   0.76507987187211735],
#  0.9: [0.70948398973480342,
#   0.87718561614993407,
#   0.8921647954846168,
#   0.89108364066010848,
#   0.87942750638255063,
#   0.87747459009805984,
#   0.89617264313835854,
#   0.91614582686531609,
#   0.90094183657269933,
#   0.89232491799703684,
#   0.91457352279343573]}

# %% [markdown]
# # Classic methods

# %% [markdown]
# ## Unsupervised

# %%
y_test_rescale = np.where(y_test == 0, np.ones((y_test.shape)), -np.ones((y_test.shape)))

# %%
unsupervised_pr_aucs = {}
unsupervised_roc_aucs = {}

# %%
from sklearn import svm
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor


classifiers_classic_uns = {
    "One-Class SVM": svm.OneClassSVM(nu=0.03,
                                     kernel="rbf", gamma=1e-5),
    "Isolation Forest": IsolationForest(n_estimators=500,
                                        max_samples=1500,
                                        contamination=0.03,
                                        random_state=10)
}


for i, (clf_name, clf) in enumerate(classifiers_classic_uns.items()):
        clf.fit(X_good)
        #scores_pred = clf.decision_function(X_test)
        y_pred = clf.predict(X_test)
        
        print (clf_name)
        print ("recall_score ",recall_score(-y_test_rescale, np.round(-y_pred)))
        print ("precision_score ",precision_score(-y_test_rescale, np.round(-y_pred)))
        print ("f1_score ",f1_score(-y_test_rescale, np.round(-y_pred)))
        print ("confusion_matrix ")
        print (confusion_matrix(-y_test_rescale, np.round(-y_pred)))
        


        Score = clf.decision_function(X_test)
        
        
        precision, recall, _ = precision_recall_curve(-y_test_rescale, -Score)
        pr_auc = auc(recall, precision)
        unsupervised_pr_aucs[clf_name]=pr_auc      
        
        plt.figure()
        plt.plot(recall, precision, label='PR curve (area = %0.3f)' % pr_auc)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.legend(loc="lower right")
        plt.grid(True)
        plt.show()
        
        fpr, tpr, _ = roc_curve(-y_test_rescale, -Score)
        roc_auc = auc(fpr, tpr)
        unsupervised_roc_aucs[clf_name]=roc_auc
        
        plt.figure()
        plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.legend(loc="lower right")
        plt.grid(True)
        plt.show()
# Out:
# One-Class SVM
# recall_score  0.787234042553
# precision_score  0.4625
# f1_score  0.582677165354
# confusion_matrix
# [[1796   43]
#  [  10   37]]
# Isolation Forest
# recall_score  0.914893617021
# precision_score  0.409523809524
# f1_score  0.565789473684
# confusion_matrix
# [[1777   62]
#  [   4   43]]

# %% [markdown]
# ## Supervised

# %%
import xgboost as xgb
from sklearn.metrics import roc_auc_score, average_precision_score

# %%
classifiers_classic_sup = {
    "XGBClassifier": xgb.XGBClassifier(n_estimators=60, max_depth=10, nthread=-1, seed=111)
}

# %%
supervised_pr_aucs = {}
supervised_roc_aucs = {}

# %%
for i, (clf_name, clf) in enumerate(classifiers_classic_sup.items()):
    for i in range(1,n_splits+1):
        if step*i>len(X_bad):
            end_ind=len(X_bad)
        else:   
            end_ind=step*i   
        clf.fit(np.concatenate((X_good, X_bad[:end_ind])), 
                np.concatenate((np.zeros((X_good.shape[0],1)), np.ones((end_ind,1)))).ravel()) 
        y_pred = clf.predict_proba(X_test)[:,1]
        if clf_name in supervised_pr_aucs:
            # append the new number to the existing array at this slot
            supervised_pr_aucs[clf_name].append(average_precision_score(y_test, y_pred))
            supervised_roc_aucs[clf_name].append(roc_auc_score(y_test, y_pred))
        else:
            # create a new array in this slot
            supervised_pr_aucs[clf_name] = [average_precision_score(y_test, y_pred)]
            supervised_roc_aucs[clf_name] = [roc_auc_score(y_test, y_pred)]

# %% [markdown]
# ## All together

# %%
supervised_pr_aucs['XGBClassifier'].insert(0, 0.5), supervised_roc_aucs['XGBClassifier'].insert(0, 0.5)
supervised_pr_aucs, supervised_roc_aucs
# Out:
# ({'XGBClassifier': [0.5,
#    0.87146559818989755,
#    0.87772630047017441,
#    0.88719163442785909,
#    0.89825447473935505,
#    0.87684597543447851,
#    0.95096526873823706,
#    0.94705056859345038,
#    0.9497651530676775,
#    0.95140682979334068,
#    0.95154191929013232]},
#  {'XGBClassifier': [0.5,
#    0.99538949243923036,
#    0.99409369106706946,
#    0.99496720002776717,
#    0.99511760554417872,
#    0.99550518899031615,
#    0.99848437518077593,
#    0.99852486897365589,
#    0.99858850207675309,
#    0.9986000717318616,
#    0.99861164138697023]})

# %%
unsupervised_roc_aucs['Isolation Forest'] = np.ones((11))*unsupervised_roc_aucs['Isolation Forest']
unsupervised_pr_aucs['Isolation Forest'] = np.ones((11))*unsupervised_pr_aucs['Isolation Forest']
unsupervised_roc_aucs['One-Class SVM'] = np.ones((11))*unsupervised_roc_aucs['One-Class SVM']
unsupervised_pr_aucs['One-Class SVM'] = np.ones((11))*unsupervised_pr_aucs['One-Class SVM']

unsupervised_pr_aucs, unsupervised_roc_aucs
# Out:
# ({'Isolation Forest': array([ 0.7764396,  0.7764396,  0.7764396,  0.7764396,  0.7764396,
#           0.7764396,  0.7764396,  0.7764396,  0.7764396,  0.7764396,
#           0.7764396]),
#   'One-Class SVM': array([ 0.64633933,  0.64633933,  0.64633933,  0.64633933,  0.64633933,
#           0.64633933,  0.64633933,  0.64633933,  0.64633933,  0.64633933,
#           0.64633933])},
#  {'Isolation Forest': array([ 0.98918237,  0.98918237,  0.98918237,  0.98918237,  0.98918237,
#           0.98918237,  0.98918237,  0.98918237,  0.98918237,  0.98918237,
#           0.98918237]),
#   'One-Class SVM': array([ 0.9868453,  0.9868453,  0.9868453,  0.9868453,  0.9868453,
#           0.9868453,  0.9868453,  0.9868453,  0.9868453,  0.9868453,
#           0.9868453])})

# %%
ours_pr_aucs
# Out:
# {0.05: [0.75997654184597851,
#   0.77734889649161554,
#   0.80757581457946825,
#   0.82053944561747794,
#   0.85732590424244148,
#   0.76689311308391239,
#   0.80870170651658757,
#   0.80237588402402915,
#   0.82983569228727883,
#   0.81418095767521614,
#   0.77942563545489707],
#  1: [0.84583204585042449,
#   0.87589386768602695,
#   0.87389675309950021,
#   0.88215975649688383,
#   0.89186638916879257,
#   0.9152079407232967,
#   0.93122504505830273,
#   0.91812675873387795,
#   0.90502002621854705,
#   0.92872010289320506],
#  'ours with alpha=0.': [0.81085061105545786],
#  0.5: [0.73354236736929046,
#   0.84932576460772968,
#   0.87550487207546357,
#   0.87790078932382509,
#   0.8626999242277722,
#   0.85076193991048477,
#   0.88614001278886112,
#   0.87167865052443982,
#   0.88438506302803788,
#   0.8669312258423697,
#   0.87507388996079416],
#  0.3: [0.79000231385966313,
#   0.83436188456813198,
#   0.8153769452347408,
#   0.8636627301810994,
#   0.85314787637668321,
#   0.85192420913372224,
#   0.86820861652084191,
#   0.81872609110299155,
#   0.81368407954941657,
#   0.84150034666815454,
#   0.83123282663184483],
#  0.1: [0.80656423999591931,
#   0.81219683417974842,
#   0.85108653389245736,
#   0.86081806339963918,
#   0.81988085892892182,
#   0.84523138182853808,
#   0.84918002516869506,
#   0.84688343493447216,
#   0.81813907089651838,
#   0.75826996089360166,
#   0.76507987187211735],
#  0.9: [0.70948398973480342,
#   0.87718561614993407,
#   0.8921647954846168,
#   0.89108364066010848,
#   0.87942750638255063,
#   0.87747459009805984,
#   0.89617264313835854,
#   0.91614582686531609,
#   0.90094183657269933,
#   0.89232491799703684,
#   0.91457352279343573]}

# %%
ours_pr_aucs['ours with alpha=0.'] = np.ones((11))*ours_pr_aucs['ours with alpha=0.']
ours_roc_aucs['ours with alpha=0.'] = np.ones((11))*ours_roc_aucs['ours with alpha=0.']

# %%
ours_pr_aucs[1.0].insert(0, 0.5)
ours_roc_aucs[1.0].insert(0, 0.5)

# %%
#ours_pr_aucs, ours_roc_aucs

# %%
all_methods = [*unsupervised_pr_aucs.keys(),*ours_pr_aucs.keys(),*supervised_roc_aucs.keys()]

# %%
pr_s = {k: v for d in (unsupervised_pr_aucs, ours_pr_aucs, supervised_pr_aucs) for k, v in d.items()}
roc_s = {k: v for d in (unsupervised_roc_aucs, ours_roc_aucs, supervised_roc_aucs) for k, v in d.items()}

# %%
roc_s
# Out:
# {0.05: [0.98846505385674455,
#   0.98775930489512109,
#   0.98950632281651685,
#   0.98895097937130494,
#   0.99359041106984602,
#   0.98793284972174977,
#   0.98920551178369376,
#   0.99073270625802645,
#   0.98849976282207019,
#   0.98983027315955718,
#   0.9883724966158759],
#  1: [0.5,
#   0.95145372716439325,
#   0.96750083879999538,
#   0.98891627040597929,
#   0.96352087744264348,
#   0.99493249106244142,
#   0.97970682493954864,
#   0.99832240000925565,
#   0.99816042483773559,
#   0.99806208276931263,
#   0.99819513380306135],
#  'One-Class SVM': array([ 0.9868453,  0.9868453,  0.9868453,  0.9868453,  0.9868453,
#          0.9868453,  0.9868453,  0.9868453,  0.9868453,  0.9868453,
#          0.9868453]),
#  'XGBClassifier': [0.5,
#   0.99538949243923036,
#   0.99409369106706946,
#   0.99496720002776717,
#   0.99511760554417872,
#   0.99550518899031615,
#   0.99848437518077593,
#   0.99852486897365589,
#   0.99858850207675309,
#   0.9986000717318616,
#   0.99861164138697023],
#  0.5: [0.89986463503522973,
#   0.99293094072865684,
#   0.9939375007231035,
#   0.99333587865745709,
#   0.99310448555528563,
#   0.99169298763203861,
#   0.99538370761167616,
#   0.99481679451135563,
#   0.99440028692744664,
#   0.99517545381972172,
#   0.99460854071940108],
#  0.1: [0.98784607730843543,
#   0.99112607453171819,
#   0.99289623176333108,
#   0.99327803038191431,
#   0.99200536831997033,
#   0.99033933798433471,
#   0.99067485798248345,
#   0.99131118901345561,
#   0.99061700970694067,
#   0.98391817939907222,
#   0.98944847454097395],
#  0.3: [0.98819895178924722,
#   0.98993440005553435,
#   0.98957574074716836,
#   0.99330116969213145,
#   0.99310448555528563,
#   0.99121863177258696,
#   0.9930234979695256,
#   0.99062857936204929,
#   0.9930929159001769,
#   0.99284995314289681,
#   0.99184339314845016],
#  'ours with alpha=0.': array([ 0.9864635,  0.9864635,  0.9864635,  0.9864635,  0.9864635,
#          0.9864635,  0.9864635,  0.9864635,  0.9864635,  0.9864635,
#          0.9864635]),
#  0.9: [0.97252206911711958,
#   0.99457383175407543,
#   0.99615887450395102,
#   0.99533742899124178,
#   0.99567294898939063,
#   0.99397220968842914,
#   0.99599689933243085,
#   0.99744310622100363,
#   0.99699767449932331,
#   0.99573658209248783,
#   0.99709601656774616],
#  'Isolation Forest': array([ 0.98918237,  0.98918237,  0.98918237,  0.98918237,  0.98918237,
#          0.98918237,  0.98918237,  0.98918237,  0.98918237,  0.98918237,
#          0.98918237])}

# %%
def plot_for_comparison(dic, names, ylabel="PR AUC", y_lim_min=0.3):
    plt.figure(figsize=(9,9))
    for i, name in enumerate(names):
        plt.plot(np.arange(0, 1.1, 0.1), dic[name], label=name)
    
    plt.ylabel(ylabel)
    plt.ylim(y_lim_min, 1.)
    plt.xlabel("% of used anomalies")
    plt.xlim(0,1)
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# %%
plot_for_comparison(pr_s, all_methods, ylabel="PR AUC")

# %%
plot_for_comparison(roc_s, all_methods, ylabel="ROC AUC", y_lim_min=0.9)
